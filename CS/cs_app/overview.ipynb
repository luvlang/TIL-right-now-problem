# %% [markdown]
# # Book Overview
# - ch1: 간단한 프로그램(Hello world)의 life cycle을 따라가기
# tracing the life cycle fo a simple program("hello world")
# - ch2: computer arithmetic - properties of unsigned, how numbers are represented, two's complement number representations, casting between signed and unsigned numbers, arithmetic operation(mathematical properties)
# - ch3: how to read the x86-64 machine code generated by a C compiler
#   - instruction patterns
# 		- control construct: conditionals, loops, switch
# 	- implementation of procedures: stack allocation, register usage conventions, parameter passing
# 	- data structure: structres, union, arrays
# 	- instructions that implement both integer and floating-point arithmetic.
# 	- machine level view of programs: code security vulnerabilities, buffer overflow
# - ch4: basic combinational & sequential logic elements -> datapath(Y86-64)
# 	- single cycle -> pipelining(step to process instruction implemented as seperate stages)
# 	- HCL(control logic for processor design) -> generate Verilog
# - ch5: improving code performance
